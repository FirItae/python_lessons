# %% [markdown]
# # Домашнее задание - Урок 1 Python
#
# ## Основы программирования на Python
#
# **Темы урока:**
# - Функции и вызов функций
# - Переменные
# - Числа и строки
# - Ввод данных с клавиатуры
# - F-строки
#
# ---
#
# ### Инструкции по выполнению:
# 1. Выполните все задания по порядку
# 2. Запустите ячейку с кодом (Shift+Enter)
# 3. Проверьте правильность выполнения
# 4. Сохраните файл и отправьте преподавателю
#
#
#
# ---
#
# **Удачи в выполнении домашнего задания! 🚀**

# %% [markdown]
# ## Задание 1. Работа с функциями print()
#
# Выведите на экран следующие сообщения:
# 1. Своё имя и фамилию
# 2. Свой возраст
# 3. Название своего любимого предмета
# 4. Пустую строку (используя print() без аргументов)

# %%
# Ваш код здесь
# Пример работы:
# Иван Петров
# 15 лет
# Математика
# (пустая строка)

# %% [markdown]
# ## Задание 2. Переменные и арифметические операции
#
# Создайте переменные и выполните вычисления:
# 1. Создайте переменную `a` со значением 15
# 2. Создайте переменную `b` со значением 7
# 3. Вычислите и выведите:
#    - Сумму a и b
#    - Разность a и b
#    - Произведение a и b
#    - Частное a и b
#    - Остаток от деления a на b
#    - Целую часть от деления a на b

# %%
# Ваш код здесь
# Пример работы:
# Сумма: 22
# Разность: 8
# Произведение: 105
# Частное: 2.142857142857143
# Остаток: 1
# Целая часть: 2

# %% [markdown]
# ## Задание 3. Работа со строками
#
# 1. Создайте переменную `first_name` со своим именем
# 2. Создайте переменную `last_name` со своей фамилией
# 3. Создайте переменную `full_name`, соединив имя и фамилию
# 4. Выведите:
#    - Полное имя
#    - Первый символ имени
#    - Последний символ фамилии
#    - Длину полного имени
#    - Имя, повторённое 3 раза
#    - Фамилию и инициал (например, "Петров И.")

# %%
# Ваш код здесь
# Пример работы:
# Полное имя: Иван Петров
# Первый символ имени: И
# Последний символ фамилии: в
# Длина полного имени: 11
# Имя, повторённое 3 раза: ИванИванИван
# Фамилия и инициал: Петров И.

# %% [markdown]
# ## Задание 4. Ввод данных с клавиатуры
#
# 1. Попросите пользователя ввести его имя
# 2. Попросите пользователя ввести его возраст
# 3. Попросите пользователя ввести его любимое число
# 4. Выведите приветствие, используя введённые данные

# %%
# Ваш код здесь
# Подсказка: используйте input() для ввода данных
# Пример работы:
# Введите ваше имя: Анна
# Введите ваш возраст: 16
# Введите ваше любимое число: 7
# Привет, Анна! Вам 16 лет, а ваше любимое число - 7!

# %% [markdown]
# ## Задание 5. F-строки
#
# Создайте программу-калькулятор возраста:
# 1. Попросите пользователя ввести год рождения
# 2. Вычислите текущий возраст (предположим, что сейчас 2025 год)
# 3. Используя f-строки, выведите:
#    - "Вам X лет" (где X - вычисленный возраст)
#    - "В 2030 году вам будет Y лет" (где Y - возраст в 2030 году)
#    - "Вы родились в T году" (где T - введённый год рождения)

# %%
# Ваш код здесь
# Подсказка: используйте f'текст {переменная} текст'
# Пример работы:
# Введите год рождения: 2008
# Вам 17 лет
# В 2030 году вам будет 22 лет
# Вы родились в 2008 году

# %% [markdown]
# ## Задание 6. Преобразование типов данных
#
# 1. Создайте переменную `number_str` со строковым значением "42"
# 2. Преобразуйте её в целое число и сохраните в переменную `number_int`
# 3. Преобразуйте `number_int` в число с плавающей точкой и сохраните в `number_float`
# 4. Выведите все три переменные и их типы
# 5. Выполните арифметические операции с преобразованными числами

# %%
# Ваш код здесь
# Подсказка: используйте int() и float() для преобразования типов
# type() - функция, которая возвращает тип данных
# Пример работы:
# number_str = '42' 
# Тип number_str: <class 'str'>
# number_int = 42
# Тип number_int: <class 'int'>
# number_float = 42.0
# Тип number_float: <class 'float'>
# 42 + 42.0 = 84.0
# 42 - 42.0 = 0.0
# 42 + 42 = 84
# 42 - 42 = 0
# 42 * 42.0 = 1764.0
# 42 / 42.0 = 1.0
# 42 * 42 = 1764
# 42 / 42 = 1

# %% [markdown]
# ## Задание 7. Математические вычисления
#
# Создайте программу для вычисления площади и периметра прямоугольника:
# 1. Попросите пользователя ввести длину прямоугольника
# 2. Попросите пользователя ввести ширину прямоугольника
# 3. Вычислите площадь (длина × ширина)
# 4. Вычислите периметр (2 × (длина + ширина))
# 5. Выведите результаты в красивом формате

# %%
# Ваш код здесь
# Пример работы:
# Вы ввели длину прямоугольника: 5
# Вы ввели ширину прямоугольника: 3
# Площадь прямоугольника: 15
# Периметр прямоугольника: 16

# %% [markdown]
# ## Задание 8. Калькулятор времени
#
# Создайте простой калькулятор времени:
# 1. Попросите пользователя ввести количество часов
# 2. Попросите пользователя ввести количество минут
# 3. Вычислите общее количество минут (часы × 60 + минуты)
# 4. Вычислите общее количество секунд (минуты × 60)
# 5. Выведите результаты в красивом формате с f-строками
# 6. **Бонус:** Добавьте вычисление количества дней (если часов больше 24)

# %%
# Ваш код здесь
# Подсказки:
# - Используйте input() для ввода часов и минут
# - Не забудьте преобразовать ввод в числа с помощью int()
# - Для вычислений используйте арифметические операции: *, +, /
# - Для бонуса: используйте условие if для проверки часов > 24
# Пример работы:
# Введите количество часов: 2
# Введите количество минут: 30
# Общее количество минут: 150
# Общее количество секунд: 9000
# Бонус: Количество дней: 0

# %% [markdown]
# ### Задание 9. Калькулятор скидки
# Создайте программу для расчета скидки в магазине:
# 1. Попросите пользователя ввести стоимость товара
# 2. Попросите пользователя ввести процент скидки
# 3. Вычислите размер скидки (стоимость × процент / 100)
# 4. Вычислите итоговую стоимость (стоимость - скидка)
# 5. Выведите все результаты в красивом формате
# 6. **Бонус:** Добавьте проверку - если скидка больше 50%, выведите предупреждение

# %%
# Ваш код здесь
# Подсказки:
# - Используйте input() для ввода стоимости и процента
# - Не забудьте преобразовать ввод в числа с помощью int() или float()
# - Для вычисления скидки: стоимость * процент / 100
# - Для бонуса: используйте условие if для проверки скидки > 50
# Пример работы:
# Введите стоимость товара: 1000
# Введите процент скидки: 15
# Размер скидки: 150.0 рублей
# Итоговая стоимость: 850.0 рублей

# %% [markdown]
# ### Задание 10. Генератор фигур из символов
#
# **Задача:**
# Создайте программу, которая:
# 1. Попросит пользователя ввести символ для рисования (например, "#")
# 2. Попросит пользователя ввести длину фигуры (например, 5)
# 3. Выведет линию из символов заданной длины
# 4. Создаст квадрат из тех же символов
# 5. Создаст рамку из тех же символов
# 6. **Подсказка:** Используйте операцию * для повторения символов

# %%
# Ваш код здесь
# Подсказки для создания фигуры:
# - Используйте input() для ввода символа и длины
# - Применяйте операцию * для повторения символов: символ * длина
# - Используйте f-строки для красивого вывода
# - Для Прямоугольника: создайте несколько одинаковых линий 
# - Для рамки: создайте полную линию и линии с пробелами внутри
# 
# Пример работы:
# Введите символ: #
# Введите длину: 6
# Линия: #####
# 
# Прямоугольник 5x6:
# ######
# ######
# ######
# ######
# ######
# 
# Рамка 5x6:
# ######
# #    #  (решетка и 6-2 = 4 пробела и решетка)
# #    #
# #    #
# ######

# %% [markdown]
# ## Проверочные вопросы
#
# Ответьте на вопросы письменно:
#
# 1. Что такое переменная в Python?
# 2. Когда создается переменная?
# 3. Что всегда возвращает функция input()?
# 4. Как получить последний символ строки?
# 5. Что такое f-строка и зачем она нужна?
# 6. В чем разница между int() и float()?
# 7. Как убрать перенос строки в print()?
# 8. Что произойдет, если написать print без скобок в Python 3?
#
# ---
# Ответ:
