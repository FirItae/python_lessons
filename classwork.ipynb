# %% [markdown]
# ## Задача 1: Компьютерная игра
#  Создай простую игру-симулятор сбора рюкзака. Для этого:
#  1. Создай словарь предметов, где ключ - название предмета, а значение - словарь с характеристиками:
#     - вес (в кг)
#     - ценность (в золотых монетах)
#     - особая сила (например, "лечение", "защита", "атака")
#
#  2. Задай максимальный вес рюкзака (например, 15 кг)
#
#  3. Напиши программу, которая:
#     - показывает игроку список доступных предметов с их характеристиками
#     - позволяет добавлять предметы в рюкзак, пока есть место
#     - при попытке превысить максимальный вес выводит предупреждение
#     - показывает текущее содержимое рюкзака и суммарный вес
#     - подсчитывает общую ценность собранных предметов
#     - ищет предметы по особой силе
#
# Пример предметов:
# - меч (вес: 5кг, ценность: 100, сила: "атака")
# - зелье здоровья (вес: 0.5кг, ценность: 50, сила: "лечение")
# - щит (вес: 3кг, ценность: 80, сила: "защита")

# %% [markdown]
# ## Задача 2: Зоопарк
# У каждого животного в зоопарке есть своё расписание кормления и любимая еда. Создай программу, которая поможет:
# - Узнать, кого и чем кормить в определённое время
# - Составить список продуктов на день

# %% [markdown]
# ## Задача 3: Словарь эмодзи
# Создай словарь, где ключами будут слова, описывающие эмоции или действия, а значениями - соответствующие эмодзи.
# Например:
# - "радость" → "😊"
# - "грусть" → "😢"
# Добавь минимум 8 разных эмоций/действий.
# Напиши программу, которая будет заменять слова в тексте на соответствующие эмодзи!
