# %% [markdown]
# ## Задача 1: Анализ музыкальных предпочтений
# У вас есть данные о любимых жанрах музыки трёх друзей:
# - Алексей: ["рок", "поп", "джаз", "блюз"]
# - Мария: ["поп", "инди", "рэп", "рок"]
# - Иван: ["рок", "блюз", "кантри", "поп"]
#
# Найдите:
# 1. Общие для всех музыкальные жанры
# 2. Жанры, которые слушает только Алексей
# 3. Все уникальные жанры музыки, которые слушают друзья

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 2: Игровая статистика
# В онлайн-игре записывается, какие уровни прошли игроки за день:
# - Утро: [1, 2, 3, 4, 5]
# - День: [2, 4, 6, 8]
# - Вечер: [3, 5, 6, 8, 9]
#
# Определите:
# 1. Какие уровни были пройдены во все периоды дня
# 2. Какие уровни были пройдены только утром
# 3. Все уровни, которые были пройдены за день хотя бы раз

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 3: Координаты городов
# Дан список координат городов в виде кортежей (широта, долгота, название):
# ```python
# cities = [(55.7558, 37.6173, "Москва"),
#           (59.9343, 30.3351, "Санкт-Петербург"),
#           (56.8519, 60.6122, "Екатеринбург")]
# ```
#
# Задачи:
# 1. Создайте список только с названиями городов
# 2. Найдите самый северный город (с максимальной широтой)
# 3. Создайте словарь, где ключ - название города, а значение - кортеж с координатами

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 4: Каталог фильмов
# Дан список кортежей с информацией о фильмах (название, год, рейтинг):
# ```python
# movies = [("Inception", 2010, 8.8),
#          ("The Matrix", 1999, 8.7),
#          ("Interstellar", 2014, 8.6),
#          ("Avengers", 2012, 8.0)]
# ```
#
# Необходимо:
# 1. Отсортировать фильмы по рейтингу (по убыванию)
# 2. Найти все фильмы, вышедшие после 2010 года
# 3. Создать строку с названиями всех фильмов через запятую

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 5: Продажи фруктов
# Дан список кортежей с данными о продажах (товар, количество, цена за единицу):
# ```python
# sales = [("Яблоки", 5, 50),
#          ("Бананы", 3, 70),
#          ("Апельсины", 4, 60),
#          ("Яблоки", 2, 50),
#          ("Бананы", 6, 70)]
# ```
#
# Вычислите:
# 1. Общую сумму продаж
# 2. Количество проданных товаров каждого вида
# 3. Среднюю цену за единицу товара

# %%
# Ваш код здесь
