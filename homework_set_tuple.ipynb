# %% [markdown]
# ## Задача 1: Покупки
# В магазине анализируют покупки за разные дни недели:
# - Понедельник: ["хлеб", "молоко", "яйца", "сыр"]
# - Среда: ["молоко", "масло", "сыр", "творог"]
# - Пятница: ["хлеб", "сыр", "молоко", "колбаса"]
#
# Определите:
# 1. Продукты, которые покупают во все указанные дни
# 2. Уникальные продукты для каждого дня
# 3. Общий ассортимент продуктов за все дни

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 2: Анализ сотрудников
# Дан список сотрудников в виде кортежей (имя, возраст, зарплата, отдел):
# ```python
# employees = [("Иван", 25, 150000, "IT"),
#             ("Мария", 23, 100000, "HR"),
#             ("Анна", 30, 170000, "IT"),
#             ("Петр", 27, 110000, "HR")]
# ```
#
# Определите:
# 1. Среднюю зарплату по каждому отделу
# 2. Самого высокооплачиваемого сотрудника
# 3. Список всех сотрудников младше 30 лет

# %%
# Ваш код здесь

# %% [markdown]
# ## Задача 3: Расписание занятий
# Дано расписание занятий в виде кортежей (предмет, время начала, продолжительность в минутах):
# ```python
# schedule = [("Математика", "09:00", 45),
#             ("Физика", "10:00", 45),
#             ("История", "11:00", 45),
#             ("Литература", "12:00", 45)]
# ```
#
# Необходимо:
# 1. Создать список всех предметов
# 2. Посчитать общую продолжительность занятий
# 3. Определить время окончания последнего урока

# %%
# Ваш код здесь
